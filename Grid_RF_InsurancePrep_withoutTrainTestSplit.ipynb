# %%
import pandas as pd
dataset = pd.read_csv("insurance_pre.csv")
 
 
# Data preprocessing
#convert the classification(non numerical) data to Numerical
dataset= pd.get_dummies(dataset, drop_first= True) # removes the duplicate infering column

#Identify the Input and Output
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset['charges']

# #split to train and test data
# from sklearn.model_selection import train_test_split
# X_train, X_test, Y_train, Y_test = train_test_split(independent, dependent, test_size= 0.3, random_state= 0)

#standardize the input
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.fit_transform(X_test)

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid= { 'criterion': [ "absolute_error", "squared_error", "friedman_mse", "mse", "mae"],
             'max_features' : [None, "auto", "sqrt", "log2"],
             'n_estimators' : [10, 100, 200],
             'oob_score' : [True, False],
            'random_state' :  [30, 42, 50]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs= -1)
grid.fit(independent,dependent)

#y_grid_prediction = grid.predict(X_test)
# evalulate metrics R2 score
# from sklearn.metrics import r2_score
# r_score = r2_score(Y_test, y_grid_prediction)
print("BEFORE the input data split, here is the bestparams_ The R Score value for the best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 50}:  0.8700703138806669
      
print( "without train test data split R Score value for the best parameter {} : ".format(grid.best_params_) )
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# C:\Users\mpriy\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 990 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 182 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\mpriy\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\mpriy\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
The R Score value for the best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 50}:  0.8700703138806669
